# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense
from tensorflow.keras.models import Model

# Load the dataset
df = pd.read_csv("C:/Users/Jabasingh Daniel/Desktop/EGDK/Dataset/cobol_sum.csv")

# %%
summary = df['summary'].values
summary = ['<start> ' + text + ' <end>' for text in summary]

# %%
summary
# Out:
# ['<start> display the message "HELLO WORLD!" on the screen <end>',
#  '<start>  program accepts user input, displays the input along with a message, and then displays "HELLO WORLD! <end>',
#  '<start> COBOL code defines a variable named USERINP with a size of 10 characters, allowing it to store up to 10 characters of alphanumeric user input <end>',
#  '<start> Declares a numeric variable NUM1 with a picture clause of 2 digits and an initial value of 10. <end>',
#  '<start> A loop that iterates from 1 to 10, displaying the value of {LOOP_VAR} in each iteration. <end>',
#  '<start> Conditional statement checking if {VAR1} equals 10 and displaying appropriate messages. <end>',
#  '<start> Opens a file named {FILE} for input. <end>',
#  '<start> Reads a record from {FILE} into {RECORD}. <end>',
#  '<start> Closes the file {FILE}. <end>',
#  '<start> Declares an array of 10 numeric items. <end>',
#  '<start> Calls a subroutine with a parameter. <end>',
#  "<start> Declares a string variable {STRING1} with a length of 10 characters and an initial value of 'HELLO'. <end>",
#  "<start> Concatenates 'WORLD' to {STRING1}. <end>",
#  "<start> Checks if {STRING1} is equal to 'HELLO' and displays 'GREETING' if true. <end>",
#  "<start> Declares a boolean flag {BOOL_FLAG} with an initial value of 'T'. <end>",
#  "<start> Checks if {BOOL_FLAG} is 'T' and displays 'FLAG IS TRUE' or 'FLAG IS FALSE' <end>",
#  "<start> Declares a date variable {DATE_VAL} with an initial value of '20230514'. <end>",
#  '<start> Moves the current date to {DATE_VAL}. <end>',
#  '<start> Divides {VAR1} by 2 and stores the result in {RESULT}. <end>',
#  '<start> Multiplies {VAR1} by 5 and stores the result in {RESULT}. <end>',
#  "<start> Checks if {SWITCH} is 'Y' and displays 'YES', otherwise displays 'NO'. <end>",
#  '<start> Performs a loop until {VAR1} is greater than 10, adding 1 to {VAR1} in each iteration. <end>',
#  '<start> Performs a loop from 1 to 5, displaying the value of {COUNTER} in each iteration. <end>',
#  '<start> Adds {PRICE} to {TOTAL}. <end>',
#  '<start> Subtracts 5 from {TEMP}. <end>',
#  '<start> Computes the sum of {VAR1} and {VAR2} and stores it in {RESULT}. <end>',
#  '<start> display the message "HELLO WORLD!" on the screen <end>',
#  '<start> program accepts user input, displays the input along with a message, and then displays "HELLO WORLD! <end>',
#  '<start> COBOL code defines a variable named USERINP with a size of 10 characters, allowing it to store up to 10 characters of alphanumeric user input <end>',
#  '<start> the WORKING-STORAGE SECTION defines two numeric variables, NUM1 and NUM2, each capable of holding two digits. <end>',
#  '<start> The PIC 9(2) clause specifies that these variables are numeric (9) and can hold up to 2 digits. <end>',
#  '<start> COBOL code use the ACCEPT statement to read input from the user into the NUM1 and NUM2 variables. <end>',
#  '<start> group data item named G1 consisting of three sub-fields YY, MM, and DD, each capable of storing a 2-character alphanumeric value, representing a date in the format YYMMDD. <end>',
#  '<start> group data item named G2, which represents a date in the format DDMMYY. It consists of three sub-fields: DD for the day 2 characters, MM for the month 2 characters and YY for the year 2 characters The FILLER keyword is used to insert a hyphen between the day, month, and year fields for formatting purposes. <end>',
#  '<start> Performs a loop from 1 to 5, displaying the value of {COUNTER} in each iteration. <end>',
#  '<start> Adds {PRICE} to {TOTAL}. <end>',
#  '<start> Subtracts 5 from {TEMP}. <end>',
#  '<start> Computes the sum of {VAR1} and {VAR2} and stores it in {RESULT}. <end>',
#  '<start> Sets the value of {INDEX} to 5. <end>',
#  '<start> Multiplies {VAR1} by {VAR2} and stores the result in {ACCUMULATOR}. <end>',
#  '<start> Checks if {VAR1} exceeds {MAX-VALUE} and displays a message if true. <end>',
#  '<start> Performs a sub-process varying {VAR1} from 1 by 2 until {VAR1} is greater than 10. <end>',
#  '<start> Adds {INCREMENT} to {COUNTER}. <end>',
#  '<start> Divides {COUNTER} by {FACTOR} and stores the result in {RESULT}. <end>',
#  '<start> Divides {DIVIDEND} by {DIVISOR} and stores the quotient in {QUOTIENT}. <end>',
#  '<start> Adds {A} and {B} and stores the sum in {SUM}. <end>',
#  '<start> Declares a double variable {DOUBLE_VAR} with a value of +123.45. <end>',
#  '<start> Declares a negative variable {NEGATIVE_VAR} with a value of -6789. <end>',
#  "<start> Declares a character variable {CHAR_VAR} with a value of 'HELLO'. <end>",
#  '<start> Declares a date variable {DATE_VAR} with a value of 202105. <end>',
#  "<start> Declares a boolean variable {BOOL_VAR} with a value of 'T'. <end>",
#  '<start> Declares a record variable {RECORD_VAR} redefines {CHAR_VAR}. <end>',
#  '<start> Declares a group variable {GROUP_VAR} with two subvariables {SUBVAR1} and {SUBVAR2}. <end>',
#  '<start> Declares a table variable {TABLE_VAR} with 5 occurrences of 3-digit numbers. <end>',
#  '<start> Moves the value 12345 to {CHAR_VAR}. <end>',
#  "<start> Moves the value 'WORLD' to {STRING_VAR}. <end>",
#  "<start> Performs a loop from 1 to 5, displaying 'Hello' in each iteration. <end>",
#  '<start> Checks if {VAR1} is greater than {VAR2} and displays the appropriate message. <end>',
#  '<start> Divides {VAR1} by {VAR2}, stores the result in {RESULT}, and the remainder in {REMAINDER}. <end>',
#  "<start> Checks if {FLAG} is 'Y' and moves 'YES' to {ANSWER}, otherwise moves 'NO'. <end>",
#  "<start> Sets the value of {FLAG} to 'N'. <end>",
#  '<start> Multiplies {VAR1} by {VAR2}. <end>',
#  '<start> Adds {VAR1} and {VAR2} and stores the sum in {RESULT}. <end>',
#  '<start> Subtracts {VAR2} from {VAR1} and stores the difference in {RESULT}. <end>',
#  '<start> Performs a sub-process from {SUB-PROCESS} to {END-PROCESS}. <end>',
#  '<start> Adds 10 to {VAR1}, 20 to {VAR2}, and stores the sum in {RESULT}. <end>',
#  "<start> Moves the value 'ABCD' to {STRING_VAR}. <end>",
#  '<start> Moves the value 1234567890 to {BIG_NUMBER_VAR}. <end>',
#  '<start> Sets the value of {FLAG1} to {FLAG2}. <end>',
#  '<start> Divides {NUMERATOR} by {DENOMINATOR}, stores the quotient in {QUOTIENT}, and the remainder in {REMAINDER}. <end>',
#  '<start> Checks if {FLAG1} is greater than {FLAG2} and displays the appropriate message. <end>',
#  '<start> Checks if {VAR1} is less than or equal to {VAR2} and displays the appropriate message. <end>',
#  '<start> Performs a loop until {VAR1} is greater than 30, displaying {VAR1} in each iteration. <end>',
#  '<start> Performs a loop from 1 to 5, adding {VAR1} to {SUM} in each iteration. <end>',
#  '<start> Computes the result of ({VAR1} + {VAR2}) * {FACTOR} and stores it in {RESULT}. <end>',
#  "<start> Moves the value 'GOODBYE' to {STRING_VAR} from {STRING_VAR2}. <end>",
#  "<start> Checks if {VAR1} equals {VAR2} and moves 'EQUAL' or 'NOT EQUAL' to {RESULT} accordingly. <end>",
#  '<start> Performs a loop from 1 to 5 executing a sub-process from {SUB-PROCESS} to {END-PROCESS}. <end>',
#  '<start> Divides {VAR1} by {VAR2} and checks if the result is 0, displaying a message if true. <end>',
#  '<start> Declares a numeric variable {NUMERIC-VAR} with a value of 123. <end>',
#  '<start> Declares a decimal variable {DECIMAL-VAR} with a value of 123.45. <end>',
#  "<start> Checks if {FLAG} is not equal to 'Y' and displays a message if true. <end>",
#  "<start> Performs a sub-process until {FLAG} becomes 'Y'. <end>",
#  '<start> Moves values 1 to 5 into array {ARRAY}. <end>',
#  '<start> Checks if {VAR1} equals 10 or {VAR2} equals 20, displaying a message if true. <end>',
#  "<start> Checks if {FLAG} is 'Y' and {NUMERIC-VAR} equals 100, displaying a message if both conditions are true. <end>",
#  '<start> Checks the value of {VAR1} and performs different sub-processes based on its value. <end>',
#  '<start> Declares a table variable {TABLE-VAR} with 5 occurrences, each containing {SUB-VAR1} and {SUB-VAR2}. <end>',
#  "<start> Moves the date '20240101' to {DATE-VAR} and computes the next date using ADD-TO-DATE function. <end>",
#  '<start> Searches for {ITEM} and displays a message based on its value. <end>',
#  "<start> Moves 'ABC' to {STRING-VAR} and checks if it equals 'ABC', displaying a message if true. <end>",
#  '<start> Declares an amount variable {AMOUNT} with a negative value of -123.45. <end>',
#  "<start> Checks if {FLAG1} is 'Y' and {FLAG2} is 'N', displaying a message if both conditions are true. <end>",
#  "<start> Moves 'Hello' to {VAR} and splits it into words {WORD1} and {WORD2} with a count of words in {WORD-COUNT}. <end>",
#  '<start> Performs a loop from 1 to 10 with a step of 2, executing a sub-process from {SUB-PROCESS} to {END-PROCESS}. <end>',
#  '<start> Checks if {AMOUNT} is negative, displaying a message if true. <end>',
#  "<start> Concatenates {STRING1} and ' ' and {STRING2} into {RESULT}. <end>",
#  '<start> Moves 123 to {NUM} and checks if it equals 123, displaying a message if true. <end>',
#  '<start> Performs a loop from 1 to 5, executing a sub-process with each iteration. <end>',
#  "<start> Moves dates '20231231' and '20240101' to {DATE1} and {DATE2}, and checks if {DATE1} is before {DATE2}, displaying a message if true. <end>",
#  "<start> Moves 'Hello' to {STRING} and checks if it equals 'Hello', displaying a message if true. <end>",
#  "<start> Performs a loop executing a sub-process from {SUB-PROCESS} to {END-PROCESS} until {FLAG} becomes 'Y'. <end>",
#  '<start> Declares an array variable {ARRAY} with 5 occurrences of strings of length 5. <end>',
#  "<start> Moves 'ABCDEFGHIJ' to {STRING} and splits it into 5 words {WORD1} to {WORD5}. <end>",
#  '<start> Checks if {VAR} is not equal to 0, displaying a message if true. <end>',
#  "<start> Moves 'ABC' to {STRING} and splits it into words {WORD1} to {WORD3} with a count of words in {WORD-COUNT}. <end>",
#  '<start> Checks if {VAR1} is greater than 0 and {VAR2} is less than 0, displaying a message if true. <end>',
#  "<start> Checks if {FLAG} is 'Y' or 'N', displaying a message if true. <end>",
#  "<start> Performs a loop executing a sub-process from {SUB-PROCESS} to {END-PROCESS} until {FLAG} becomes 'Y'. <end>",
#  '<start> Checks if {AMOUNT} is negative and sets it to 0 if true. <end>',
#  "<start> Moves 'Hello, World!' to {STRING} and replaces all commas with spaces. <end>",
#  '<start> Checks if {VAR1} is less than {VAR2} and moves the value of {VAR2} to {VAR1} if true. <end>',
#  '<start> Declares an array variable {ARRAY} with 10 occurrences of strings of length 10. <end>',
#  "<start> Moves 'ABCD' to {STRING} and splits it into individual characters {CHAR1} to {CHAR4}. <end>",
#  '<start> Checks if {NUM} is greater than 100 and computes {RESULT} accordingly. <end>',
#  '<start> Checks the value of {FLAG} and displays the appropriate message. <end>',
#  '<start> Declares a numeric variable {NUM} with an initial value of 12345. <end>',
#  '<start> Declares an amount variable {AMOUNT} with a negative value of -123.45. <end>',
#  '<start> Checks if {VAR1} is greater than or equal to {VAR2} and displays a message if true. <end>',
#  '<start> Checks if {VAR1} is not greater than {VAR2} and displays a message if true. <end>',
#  '<start> Declares {NUM1} and {NUM2} with initial values of 100 and 200 respectively, then computes the sum into {RESULT}. <end>',
#  '<start> Performs a loop executing a sub-process until {COUNTER} becomes greater than 100. <end>',
#  '<start> Declares a numeric variable {VAR} with an initial value of zero. <end>',
#  "<start> Declares a string variable {STRING} with an initial value of 'HELLO WORLD'. <end>",
#  '<start> Checks if {VAR} is equal to zero and assigns 1 to {VAR} if true. <end>',
#  '<start> Moves values to {NUM1} and {NUM2} then computes their sum into {RESULT}. <end>',
#  '<start> Declares a date variable {DATE} with an initial value of 20220514. <end>',
#  "<start> Moves 100 to {NUM1} and checks if it's less than 50, displaying a message accordingly. <end>",
#  '<start> Performs a loop from 1 to 10, displaying the value of {INDEX} in each iteration. <end>',
#  "<start> Declares a character variable {CHAR} with an initial value of 'A'. <end>",
#  '<start> Checks if {VAR1} is greater than {VAR2} and displays a message accordingly. <end>',
#  "<start> Performs a loop executing a sub-process from {SUB-PROCESS} to {END-PROCESS} until {FLAG} becomes 'N'. <end>",
#  '<start> Declares a counter variable {COUNTER} with an initial value of 1. <end>',
#  '<start> Declares a balance variable {BALANCE} with an initial value of 10000.50. <end>',
#  '<start> Checks if {BALANCE} is less than 1000 and displays an alert if true. <end>',
#  '<start> Moves values to {START-DATE} and {END-DATE}. <end>',
#  "<start> Declares an employee name variable {EMPLOYEE-NAME} with an initial value of 'John Doe'. <end>",
#  "<start> Checks if {FLAG} is 'Y' and displays a message accordingly. <end>",
#  '<start> Performs a loop until {INDEX} is greater than 5, displaying and incrementing the value of {INDEX} each iteration. <end>',
#  '<start> Declares a signed integer variable {TEMP} in computational format. <end>',
#  '<start> Declares a rate variable {RATE} with an initial value of 0.125. <end>',
#  '<start> Checks if {TEMP} is not zero and displays a message if true. <end>',
#  '<start> Declares a total variable {TOTAL} with an initial value of zero. <end>',
#  '<start> Moves 1000 to {TOTAL} and multiplies it by 1.05. <end>',
#  "<start> Declares a status code variable {STATUS-CODE} with an initial value of 'OK'. <end>",
#  "<start> Checks if {STATUS-CODE} is 'ER' and displays a message if true. <end>",
#  '<start> Declares a count variable {COUNT} with an initial value of 100. <end>',
#  '<start> Performs a loop from 100 to 90 in decrement, displaying the value of {COUNT} each iteration. <end>',
#  "<start> Declares a flag variable {FLAG} with an initial value of 'N'. <end>",
#  "<start> Checks if {FLAG} is not 'Y' and displays a message if true. <end>",
#  '<start> Declares a rate variable {RATE} with an initial value of 3.50. <end>',
#  '<start> Multiplies {RATE} by 2. <end>',
#  '<start> Declares a quantity variable {QUANTITY} with an initial value of 50. <end>',
#  '<start> Subtracts 10 from {QUANTITY}. <end>',
#  "<start> Declares a grade variable {GRADE} with an initial value of 'A'. <end>",
#  "<start> Checks if {GRADE} is 'A' and displays a message if true. <end>",
#  '<start> Moves 5 to {INDEX} and adds 1 to it. <end>',
#  "<start> Declares a flag variable {FLAG} with an initial value of 'Y'. <end>",
#  '<start> Declares a discount variable {DISCOUNT} with an initial value of 0.10. <end>',
#  '<start> Declares a floating-point variable {FLOAT-NUM} with an initial value of 12345.67. <end>',
#  '<start> Declares an array {ARRAY} with 10 numeric elements, each with 2 digits. <end>',
#  "<start> Declares a boolean variable {BOOL-VAR} with an initial value of 'T' (True). <end>",
#  '<start> Declares a decimal variable {DECIMAL-NUM} with an initial value of 1234.5678. <end>',
#  '<start> Declares a list {LIST-VAR} with 5 string elements, each with 10 characters. <end>',
#  '<start> Declares a dictionary {DICT-VAR} placeholder. <end>',
#  '<start> Declares a record structure {RECORD} with fields {ID} and {NAME}. <end>',
#  '<start> Declares a set variable {SET-VAR} placeholder. <end>',
#  '<start> Declares a tuple variable {TUPLE-VAR} placeholder. <end>',
#  '<start> Declares a counter variable {COUNTER} with an initial value of 1. <end>',
#  '<start> Declares a set {SET-VAR} with 5 string elements, each with 10 characters. <end>',
#  '<start> Declares a tuple {TUPLE-VAR} with 5 string elements, each with 10 characters. <end>',
#  "<start> Declares a string list {STR-LIST} with 5 elements initialized to 'STR'. <end>",
#  '<start> Declares a float list {FLOAT-LIST} with 5 elements initialized to 12.34. <end>',
#  '<start> Declares a dictionary-like record {DICT-RECORD} with key-value pairs. <end>',
#  '<start> Declares a list of records {RECORD-LIST} with 5 elements, each containing fields {ID} and {NAME}. <end>',
#  "<start> Declares a character variable {CHAR-VAR} with an initial value of 'B'. <end>",
#  '<start> Declares a decimal array {DECIMAL-ARRAY} with 10 elements. <end>',
#  "<start> Declares a boolean array {BOOL-ARRAY} with 5 elements initialized to 'T' (True). <end>",
#  '<start> Declares a complex structure {COMPLEX-STRUCTURE} with fields {FIELD1} and {FIELD2} (an array). <end>',
#  '<start> Declares an array of records {RECORD-ARRAY} with 10 elements, each containing fields {ID} and {VALUE}. <end>',
#  "<start> Declares a date variable {DATE-VAR} with an initial value of '20240101'. <end>",
#  '<start> Declares a long numeric variable {NUM-LONG} with an initial value of 123456789012345678. <end>',
#  "<start> Declares a flag variable {FLAG} with an initial value of 'Y'. <end>",
#  '<start> Declares a negative numeric variable {NEG-NUM} with an initial value of -1234. <end>',
#  "<start> Declares an email variable {EMAIL} with an initial value of 'user@example.com'. <end>",
#  "<start> Concatenates 'Hello' into {MESSAGE}. <end>",
#  "<start> Counts the number of 'A' characters in {STRING-VAR} and stores it in {COUNT}. <end>",
#  '<start> Moves corresponding fields from {SRC-RECORD} to {DEST-RECORD}. <end>',
#  "<start> Splits {COMMA-SEPARATED-VAR} by ',' into {PART1} and {PART2}. <end>",
#  '<start> Performs a loop from 1 to 10, displaying the value of {INDEX} in each iteration, testing the condition after the loop body. <end>',
#  '<start> Declares a nested record structure {NESTED-RECORD} with a sub-record {SUB-RECORD} containing fields {SUB-ID} and {SUB-NAME}. <end>',
#  '<start> Declares a multidimensional array {MULTIDIM-ARRAY} with 3 rows and 3 columns. <end>',
#  '<start> Evaluates multiple conditions and displays a message based on which condition is met. <end>',
#  '<start> Declares a list of complex records {COMPLEX-LIST} with fields {ID}, {NAME}, and {BALANCE}. <end>',
#  '<start> Declares a numeric variable {YEAR} representing a year with an initial value of 2024. <end>',
#  '<start> Declares a floating-point array {FLOAT-ARRAY} with 5 elements, each initialized to 12345.67. <end>',
#  '<start> Sorts {DATASET} on {KEY1} in ascending order, using {INPUT-FILE} and giving {OUTPUT-FILE}. <end>',
#  '<start> Declares a long string variable {STRING-LONG} with an initial value of a long string. <end>',
#  "<start> Declares an alphanumeric variable {ALPHANUM} with an initial value of 'A12345B678'. <end>",
#  '<start> Declares a monetary variable {MONEY} with a formatted initial value of 12345.67. <end>',
#  '<start> Moves the current date to {CURRENT-DATE}. <end>']

# %%
import pandas as pd

# Assuming df is your DataFrame with the 'summary' column
df['summary'] = '<start> ' + df['summary'] + ' <end>'

# %%
tokenizer_cobol = Tokenizer(filters='')
tokenizer_cobol.fit_on_texts(df['cobol_code'])
tokenizer_summary = Tokenizer(filters='')
tokenizer_summary.fit_on_texts(df['summary'])

# Define the vocabulary sizes
vocab_size_cobol = len(tokenizer_cobol.word_index) + 1
vocab_size_summary = len(tokenizer_summary.word_index) + 1

# %%
#tokenizer_cobol.index_word

# %%
#tokenizer_summary.index_word

# %%
# Prepare input-output pairs
X = tokenizer_cobol.texts_to_sequences(df['cobol_code'])
Y = tokenizer_summary.texts_to_sequences(df['summary'])
# Pad sequences
max_len_cobol = max([len(seq) for seq in X])
max_len_summary = max([len(seq) for seq in Y])

X = pad_sequences(X, maxlen=max_len_cobol, padding='post')
Y = pad_sequences(Y, maxlen=max_len_summary, padding='post')

# %%
# Shift the target sequences for training
Y_input = Y[:, :-1]
Y_output = Y[:, 1:]

# Define the Seq2Seq model
latent_dim = 512

encoder_inputs = Input(shape=(max_len_cobol,))
encoder_embedding = Embedding(vocab_size_cobol, latent_dim, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(max_len_summary-1,))
decoder_embedding = Embedding(vocab_size_summary, latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size_summary, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Compile and train the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',)
model.fit([X, Y[:,:-1]], Y.reshape(Y.shape[0], Y.shape[1], 1)[:,1:],batch_size=30, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 339ms/step - loss: 3.4975 - val_loss: 5.1694
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 3.3106 - val_loss: 5.1126
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - loss: 3.1400 - val_loss: 5.1217
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - loss: 3.1676 - val_loss: 5.1615
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - loss: 3.0582 - val_loss: 5.1187
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - loss: 3.0238 - val_loss: 5.2160
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - loss: 2.9855 - val_loss: 5.0671
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - loss: 2.8778 - val_loss: 5.0318
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 2.7340 - val_loss: 5.0093
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - loss: 2.6951 - val_loss: 5.0280
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - loss: 2.6727 - val_loss: 5.0653
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - loss: 2.6821 - val_loss: 4.9951
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - loss: 2.5755 - val_loss: 4.9928
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - loss: 2.6164 - val_loss: 4.9662
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - loss: 2.5137 - val_loss: 4.9733
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 361ms/step - loss: 2.4003 - val_loss: 4.9307
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 442ms/step - loss: 2.2821 - val_loss: 4.9750
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - loss: 2.4523 - val_loss: 4.9882
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - loss: 2.2922 - val_loss: 4.9487
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step - loss: 2.2920 - val_loss: 5.0124
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - loss: 2.1383 - val_loss: 4.9084
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - loss: 2.1860 - val_loss: 4.9957
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - loss: 2.0974 - val_loss: 4.9991
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 2.0691 - val_loss: 5.0090
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 389ms/step - loss: 2.1044 - val_loss: 4.9680
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step - loss: 2.0122 - val_loss: 4.9843
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 358ms/step - loss: 1.9809 - val_loss: 4.9464
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 393ms/step - loss: 1.8399 - val_loss: 4.9680
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 1.8962 - val_loss: 4.9390
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 284ms/step - loss: 1.8216 - val_loss: 4.9874
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 1.8024 - val_loss: 4.9835
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - loss: 1.7451 - val_loss: 4.9553
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 1.6771 - val_loss: 4.9650
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - loss: 1.6684 - val_loss: 5.0065
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - loss: 1.7010 - val_loss: 5.0241
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 1.6576 - val_loss: 4.9749
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - loss: 1.5946 - val_loss: 5.0203
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - loss: 1.5580 - val_loss: 5.0027
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - loss: 1.5607 - val_loss: 5.0452
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - loss: 1.5000 - val_loss: 4.9849
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - loss: 1.4390 - val_loss: 5.0152
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - loss: 1.4127 - val_loss: 5.0595
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - loss: 1.4343 - val_loss: 5.0100
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 1.3954 - val_loss: 5.0191
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 1.3346 - val_loss: 4.9852
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 1.3128 - val_loss: 5.0017
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - loss: 1.3122 - val_loss: 5.0858
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 305ms/step - loss: 1.2827 - val_loss: 5.0665
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 1.2367 - val_loss: 5.0005
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - loss: 1.2282 - val_loss: 5.0568
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 1.2186 - val_loss: 5.0706
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - loss: 1.2229 - val_loss: 5.0635
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 322ms/step - loss: 1.1780 - val_loss: 5.0807
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - loss: 1.1207 - val_loss: 5.0847
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 1.1312 - val_loss: 5.1062
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - loss: 1.0578 - val_loss: 5.1058
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - loss: 1.0365 - val_loss: 5.0791
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - loss: 1.0868 - val_loss: 5.1380
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - loss: 1.0000 - val_loss: 5.1468
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - loss: 0.9849 - val_loss: 5.1837
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.9808 - val_loss: 5.1723
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.9828 - val_loss: 5.1490
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 0.9612 - val_loss: 5.1621
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - loss: 0.9339 - val_loss: 5.1926
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - loss: 0.9288 - val_loss: 5.1951
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - loss: 0.9014 - val_loss: 5.2089
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.8409 - val_loss: 5.2067
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - loss: 0.8718 - val_loss: 5.1872
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - loss: 0.8408 - val_loss: 5.2308
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 0.9256 - val_loss: 5.1999
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - loss: 0.8363 - val_loss: 5.2135
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.8104 - val_loss: 5.2201
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step - loss: 0.7706 - val_loss: 5.2028
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - loss: 0.7727 - val_loss: 5.2581
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - loss: 0.7669 - val_loss: 5.3110
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.7608 - val_loss: 5.2179
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 249ms/step - loss: 0.7422 - val_loss: 5.2614
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.7311 - val_loss: 5.2696
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - loss: 0.7026 - val_loss: 5.2987
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.7080 - val_loss: 5.2772
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.6724 - val_loss: 5.3491
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - loss: 0.7025 - val_loss: 5.3312
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 489ms/step - loss: 0.6650 - val_loss: 5.3066
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - loss: 0.6363 - val_loss: 5.3390
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - loss: 0.6257 - val_loss: 5.3629
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - loss: 0.6471 - val_loss: 5.3402
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step - loss: 0.6250 - val_loss: 5.3127
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step - loss: 0.6328 - val_loss: 5.3454
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.6127 - val_loss: 5.3682
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - loss: 0.5926 - val_loss: 5.3310
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.5562 - val_loss: 5.4216
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - loss: 0.6080 - val_loss: 5.3361
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 323ms/step - loss: 0.5856 - val_loss: 5.4163
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - loss: 0.5460 - val_loss: 5.3806
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 288ms/step - loss: 0.5310 - val_loss: 5.3976
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.5384 - val_loss: 5.4114
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 271ms/step - loss: 0.5286 - val_loss: 5.4356
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - loss: 0.5543 - val_loss: 5.3885
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 0.5158 - val_loss: 5.4318
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.5355 - val_loss: 5.4226

# %%
# Save the model
model.save('seq2seq_model.keras')

# %%
#testing

import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

# Assuming your test data is loaded and preprocessed similarly to the training data
df_test = pd.read_csv("C:/Users/Jabasingh Daniel/Desktop/EGDK/Dataset/test.csv")
X_test = tokenizer_cobol.texts_to_sequences(df_test['cobol_code'])
Y_test = tokenizer_summary.texts_to_sequences(df_test['summary'])

X_test = pad_sequences(X_test, maxlen=max_len_cobol, padding='post')
Y_test = pad_sequences(Y_test, maxlen=max_len_summary, padding='post')

# Load the trained model
model = load_model("C:/Users/Jabasingh Daniel/Desktop/EGDK/modeling/seq2seq_model.keras")

# Function to calculate sequence accuracy
def sequence_accuracy(y_true, y_pred):
    correct = 0
    total = 0
    for true_seq, pred_seq in zip(y_true, y_pred):
        true_seq = true_seq[true_seq != 0]  # Remove padding
        pred_seq = pred_seq[:len(true_seq)]  # Truncate to the length of the true sequence
        if np.array_equal(true_seq, pred_seq):
            correct += 1
        total += 1
    return correct / total

# Generate predictions
Y_pred = model.predict([X_test, Y_test[:, :-1]])

# Convert predictions to sequences of token ids
Y_pred_sequences = np.argmax(Y_pred, axis=-1)

# Calculate the accuracy
accuracy = sequence_accuracy(Y_test[:, 1:], Y_pred_sequences)
print(f'Sequence Accuracy: {accuracy * 100:.2f}%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# Sequence Accuracy: 66.67%

# %%
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model("C:/Users/Jabasingh Daniel/Desktop/EGDK/modeling/seq2seq_model.keras")

def preprocess_input(cobol_code, tokenizer_cobol, max_len_cobol):
    # Tokenize the input COBOL code
    sequence = tokenizer_cobol.texts_to_sequences([cobol_code])
    # Pad the sequence
    padded_sequence = pad_sequences(sequence, maxlen=max_len_cobol, padding='post')
    return padded_sequence

# %%
def predict_summary(cobol_code, model, tokenizer_cobol, tokenizer_summary, max_len_cobol, max_len_summary):
    # Preprocess the input COBOL code
    input_seq = preprocess_input(cobol_code, tokenizer_cobol, max_len_cobol)
    
    # Initialize the decoder input
    decoder_input = np.zeros((1, max_len_summary - 1))
    
    # Predict the summary
    for i in range(max_len_summary - 1):
        output_tokens = model.predict([input_seq, decoder_input])
        sampled_token_index = np.argmax(output_tokens[0, i, :])
        decoder_input[0, i] = sampled_token_index
        
        # Stop if a zero token (padding) is predicted, indicating no more meaningful tokens
        if sampled_token_index == 0:
            break
    
    # Convert token indices back to words
    predicted_summary = []
    for token in decoder_input[0]:
        if token == 0:
            continue
        word = tokenizer_summary.index_word.get(token, '')
        predicted_summary.append(word)
    
    return ' '.join(predicted_summary)

# %%
# Define your COBOL code to be summarized
cobol_code_example = "SORT {DATASET} ON ASCENDING KEY {KEY1} USING {INPUT-FILE} GIVING {OUTPUT-FILE}."

# Predict the summary
summary = predict_summary(cobol_code_example, model, tokenizer_cobol, tokenizer_summary, max_len_cobol, max_len_summary)
print(f'Summary: {summary}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Summary: data by and the in into into {result}.
