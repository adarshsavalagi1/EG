# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense

# %%
df = pd.read_csv("C:/Users/Jabasingh Daniel/Downloads/cobol_sum.csv")

# %%
df
# Out:
#                                            cobol_code  \
# 0   IDENTIFICATION DIVISION. PROGRAM-ID. HelloWorl...
# 1   IDENTIFICATION DIVISION. PROGRAM-ID. AdditionP...
# 2   IDENTIFICATION DIVISION. PROGRAM-ID. Multiplic...
# 3   IDENTIFICATION DIVISION. PROGRAM-ID. CEE3AB2. ...
# 4   IDENTIFICATION DIVISION. PROGRAM-ID. PRG3. ENV...
# 5   IDENTIFICATION DIVISION. PROGRAM-ID. PRG4. ENV...
# 6   IDENTIFICATION DIVISION. PROGRAM-ID. PRG5. ENV...
# 7   IDENTIFICATION DIVISION. PROGRAM-ID. PRG6. ENV...
# 8   IDENTIFICATION DIVISION. PROGRAM-ID. PRG7. ENV...
# 9   IDENTIFICATION DIVISION. PROGRAM-ID. PRG8. ENV...
# 10  IDENTIFICATION DIVISION. PROGRAM-ID. PRG7. ENV...
# 11  IDENTIFICATION DIVISION. PROGRAM-ID. PRG10. EN...
# 12  IDENTIFICATION DIVISION. PROGRAM-ID. PRG10. EN...
# 13  IDENTIFICATION DIVISION. PROGRAM-ID. PRG10. EN...
# 14  IDENTIFICATION DIVISION. PROGRAM-ID. PRG14. EN...
# 15  IDENTIFICATION DIVISION. PROGRAM-ID. PRG14. EN...
# 16  MOVE "I" TO GRADE ELSE IF AVG > 60 AND AVG < 7...
# 17  IDENTIFICATION DIVISION. PROGRAM-ID. PRG7. ENV...
# 18  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 19  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 20  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 21  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 22  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 23  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 24  IDENTIFICATION DIVISION. PROGRAM-ID. PRG18. EN...
# 25  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 26  def main(): W_REC = {"W_DAYS": {"D1": "SUNDAY"...
# 27  01 WS-PAY. 05 WS-FIXED-PAY. 10 WS-BASIC PIC 9(...
# 28  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 29  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 30  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 31  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 32  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
# 33  IDENTIFICATION DIVISION. PROGRAM-ID. PRG25. EN...
#
#                                           python_code
# 0                              print('Hello, World!')
# 1   NUM1 = 100\nNUM2 = 200\nRESULT = NUM1 + NUM2\n...
# 2   NUM1 = 10\nNUM2 = 20\nRESULT = NUM1 * NUM2\npr...
# 3   def cee3ab2(abend_code, reason_code, cleanup_c...
# 4   NUM1 = int(input('Enter NUM1: ')); NUM2 = int(...
# 5   ROLLNO, STUNAME, MARK1, MARK2, MARK3 = input('...
# 6   from datetime import datetime; date_str = inpu...
# 7   EMPID = 3454; EMPID2 = EMPID; ALPNUM = 'ABC123...
# 8   TEMP = float(input('Enter a number with two de...
# 9   TEMP = int(input('Enter a number: ')); print('...
# 10  NUM1 = int(input('Enter a number (ZZ99 format)...
# 11  NUM1 = 45; NUM2 = 45; TOTAL = NUM1 + NUM2; pri...
# 12  NUM1 = int(input('Enter NUM1: ')); NUM2 = int(...
# 13  WS_A = 23.678; WS_B = 29.459; WS_TOT = WS_A + ...
# 14  CELCIUS = int(input('Enter temperature in Cels...
# 15  P = int(input('Enter principal amount: ')); R ...
# 16  GRADE = "I" if AVG >= 80 else ("II" if AVG >= ...
# 17  MARK1, MARK2, MARK3 = int(input('Enter MARK1: ...
# 18  INP_NUM = int(input('Enter a number: ')); RES ...
# 19  STOP_AT = int(input('Enter stop value: ')); IN...
# 20  NUM = int(input('Enter a number: ')); TEMP = N...
# 21  import math; def main(): start_list = int(inpu...
# 22  import math; def main(): num_1, num_2, option,...
# 23                                                NaN
# 24  import re; def main(): telephone_number = ""; ...
# 25  import sys; def main(): f_name = {"first_name"...
# 26  def main(): W_REC = {"W_DAYS": {"D1": "SUNDAY"...
# 27  WS_PAY = {"WS_FIXED_PAY": {"WS_BASIC": 0.00, "...
# 28  INP_AGE, AMOUNT = int(input("Enter age: ")), i...
# 29  INP_CHAR = input("Enter a character: ")[0]; pr...
# 30  import sys; max_num, idx, total = [0] * 5, 1, ...
# 31  import math; max_num = [0] * 50; idx = 1; rem ...
# 32  import sys; max_num = [0] * 5; idx = 1; max_va...
# 33  import math; def main(): even_odd = [0] * 100;...
