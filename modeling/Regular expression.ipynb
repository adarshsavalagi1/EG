# %%
import re

def extract_procedures_with_display(cobol_code):
    # Regular expression to match the procedure names and their DISPLAY statements
    pattern = re.compile(r'^\s*(\w+)\.\s*(.*?DISPLAY.*?)(?=\n\s*\w+\.|$)', re.DOTALL | re.MULTILINE)
    matches = pattern.findall(cobol_code)
    # Clean up the procedures
    cleaned_procedures = [(name.strip(), code.strip()) for name, code in matches]
    return cleaned_procedures

cobol_code = """
IDENTIFICATION DIVISION.
PROGRAM-ID. ExampleProgram.
AUTHOR. YourName.
DATE-WRITTEN. 20240514.

ENVIRONMENT DIVISION.

DATA DIVISION.
WORKING-STORAGE SECTION.
01 WS-NUM1        PIC 9(5) VALUE 10.
01 WS-NUM2        PIC 9(5) VALUE 20.
01 WS-RESULT      PIC 9(5).
01 WS-MESSAGE     PIC X(30).

PROCEDURE DIVISION.
MAIN-PARA.
    PERFORM ADDITION
    PERFORM SUBTRACTION
    PERFORM MULTIPLICATION
    PERFORM DIVISION
    PERFORM CONCATENATE-MESSAGE
    PERFORM REVERSE-MESSAGE
    PERFORM LENGTH-OF-MESSAGE
    PERFORM DISPLAY-HELLO
    PERFORM DISPLAY-GOODBYE
    PERFORM DISPLAY-DATE
    STOP RUN.

ADDITION.
    COMPUTE WS-RESULT = WS-NUM1 + WS-NUM2
    DISPLAY 'Addition Result: ' WS-RESULT.

SUBTRACTION.
    COMPUTE WS-RESULT = WS-NUM2 - WS-NUM1
    DISPLAY 'Subtraction Result: ' WS-RESULT.

MULTIPLICATION.
    COMPUTE WS-RESULT = WS-NUM1 * WS-NUM2
    DISPLAY 'Multiplication Result: ' WS-RESULT.

DIVISION.
    IF WS-NUM1 NOT = 0
        COMPUTE WS-RESULT = WS-NUM2 / WS-NUM1
        DISPLAY 'Division Result: ' WS-RESULT
    ELSE
        DISPLAY 'Division by zero is not allowed'.

CONCATENATE-MESSAGE.
    MOVE 'Hello, ' TO WS-MESSAGE
    STRING WS-MESSAGE DELIMITED BY SPACE
            'World!' DELIMITED BY SIZE
            INTO WS-MESSAGE
    DISPLAY 'Concatenated Message: ' WS-MESSAGE.

REVERSE-MESSAGE.
    MOVE 'COBOL' TO WS-MESSAGE
    PERFORM VARYING WS-RESULT FROM LENGTH OF WS-MESSAGE BY -1
        UNTIL WS-RESULT < 1
        DISPLAY WS-MESSAGE(WS-RESULT:1) NO ADVANCING
    END-PERFORM
    DISPLAY ' '.

LENGTH-OF-MESSAGE.
    MOVE 'COBOL Programming' TO WS-MESSAGE
    DISPLAY 'Length of Message: ' FUNCTION LENGTH(WS-MESSAGE).

DISPLAY-HELLO.
    DISPLAY 'Hello, User!'.

DISPLAY-GOODBYE.
    DISPLAY 'Goodbye, User!'.

DISPLAY-DATE.
    DISPLAY 'Current Date: ' FUNCTION CURRENT-DATE (1:8).
"""

procedures = extract_procedures_with_display(cobol_code)
for name, code in procedures:
    print(f'Procedure: {name}\n{code}\n')
# Out:
# Procedure: AUTHOR
# YourName.
# DATE-WRITTEN. 20240514.
#
# ENVIRONMENT DIVISION.
#
# DATA DIVISION.
# WORKING-STORAGE SECTION.
# 01 WS-NUM1        PIC 9(5) VALUE 10.
# 01 WS-NUM2        PIC 9(5) VALUE 20.
# 01 WS-RESULT      PIC 9(5).
# 01 WS-MESSAGE     PIC X(30).
#
# PROCEDURE DIVISION.
# MAIN-PARA.
#     PERFORM ADDITION
#     PERFORM SUBTRACTION
#     PERFORM MULTIPLICATION
#     PERFORM DIVISION
#     PERFORM CONCATENATE-MESSAGE
#     PERFORM REVERSE-MESSAGE
#     PERFORM LENGTH-OF-MESSAGE
#     PERFORM DISPLAY-HELLO
#
# Procedure: ADDITION
# COMPUTE WS-RESULT = WS-NUM1 + WS-NUM2
#     DISPLAY 'Addition Result: ' WS-RESULT.
#
# Procedure: SUBTRACTION
# COMPUTE WS-RESULT = WS-NUM2 - WS-NUM1
#     DISPLAY 'Subtraction Result: ' WS-RESULT.
#
# Procedure: MULTIPLICATION
# COMPUTE WS-RESULT = WS-NUM1 * WS-NUM2
#     DISPLAY 'Multiplication Result: ' WS-RESULT.
#
# Procedure: DIVISION
# IF WS-NUM1 NOT = 0
#         COMPUTE WS-RESULT = WS-NUM2 / WS-NUM1
#         DISPLAY 'Division Result: ' WS-RESULT
